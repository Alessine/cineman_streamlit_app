# %% [markdown]
# # Reduce the number of old movies from tmdb

# %%
import pandas as pd

# %%
movies_5000 = pd.read_csv("../data/external/tmdb_5000_movies.csv")

# %%
movies_5000.sort_values(by="popularity", ascending=False, ignore_index=True, inplace=True)

# %%
# take the 500 most popular ones
movies_750 = movies_5000.iloc[:750]
movies_750
# Out:
#         budget                                             genres  \
# 0     74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 1    165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 2     58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 4    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ..         ...                                                ...
# 745  130000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 746   68000000                     [{"id": 35, "name": "Comedy"}]
# 747   40000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 748    8000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 749   11000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
#
#                                      homepage      id  \
# 0                http://www.minionsmovie.com/  211672
# 1           http://www.interstellarmovie.net/  157336
# ...

# %%
movies_750.to_csv("../data/external/tmdb_750_movies.csv")

# %%
movies_750[movies_750["original_title"]=="올드보이"]
# Out:
#       budget                                             genres homepage   id  \
# 365  3000000  [{"id": 18, "name": "Drama"}, {"id": 53, "name...      NaN  670
#
#                                               keywords original_language  \
# 365  [{"id": 3364, "name": "sushi restaurant"}, {"i...                ko
#
#     original_title                                           overview  \
# 365           올드보이  With no clue how he came to be imprisoned, dru...
#
#      popularity                               production_companies  \
# 365    56.76349  [{"name": "Egg Films", "id": 398}, {"name": "S...
#
#                               production_countries release_date   revenue  \
# 365  [{"iso_3166_1": "KR", "name": "South Korea"}]   2003-01-01  14980005
#
#      runtime                                   spoken_languages    status  \
# 365    120.0  [{"iso_639_1": "ko", "name": "\ud55c\uad6d\uc5...  Released
#
# ...

# %%
movies_750["original_title"].tolist()
# Out:
# ['Minions',
#  'Interstellar',
#  'Deadpool',
#  'Guardians of the Galaxy',
#  'Mad Max: Fury Road',
#  'Jurassic World',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Dawn of the Planet of the Apes',
#  'The Hunger Games: Mockingjay - Part 1',
#  'Big Hero 6',
#  'Terminator Genisys',
#  'Captain America: Civil War',
#  'Whiplash',
#  'The Dark Knight',
#  'The Martian',
#  'Inception',
#  'Frozen',
#  'Batman v Superman: Dawn of Justice',
#  'Avatar',
#  'Fight Club',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Imitation Game',
#  'The Avengers',
#  'The Godfather',
#  'Teenage Mutant Ninja Turtles',
#  'Gone Girl',
#  'Pixels',
#  'Fury',
#  'X-Men: Apocalypse',
#  "Pirates of the Caribbean: At World's End",
#  'Rise of the Planet of the Apes',
#  'Forrest Gump',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Despicable Me 2',
#  'The Shawshank Redemption',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Avengers: Age of Ultron',
# ...

# %%
movies_5000.loc[750:,"original_title"].tolist()
# Out:
# ['Dark City',
#  'Some Like It Hot',
#  'Sucker Punch',
#  'Alexander',
#  'Hail, Caesar!',
#  'White House Down',
#  'Me, Myself & Irene',
#  'This Means War',
#  'The Visit',
#  'Treasure Planet',
#  'Scott Pilgrim vs. the World',
#  'Grown Ups',
#  'Valkyrie',
#  'Hostel',
#  'Contagion',
#  'Trance',
#  'Final Destination',
#  'Per un pugno di dollari',
#  'Mr. Peabody & Sherman',
#  'True Lies',
#  'No Strings Attached',
#  'Rambo: First Blood Part II',
#  'Unknown',
#  'Abraham Lincoln: Vampire Hunter',
#  'We Bought a Zoo',
#  'Hot Fuzz',
#  "Daddy's Home",
#  'Final Destination 5',
#  'The 40 Year Old Virgin',
#  'This Is 40',
#  'Zero Dark Thirty',
#  'Money Monster',
#  'The Untouchables',
#  'This Is the End',
#  'A Nightmare on Elm Street',
#  'The Boy',
#  'The Passion of the Christ',
#  'The Neon Demon',
#  'Fantastic Four',
#  'Anchorman 2: The Legend Continues',
#  'What Happens in Vegas',
#  'Zoolander',
#  'Bad Boys II',
#  'Date Night',
#  'Phone Booth',
# ...

# %%
movies_5000[movies_5000["original_title"]=="Beauty and the Beast"]
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count]
# Index: []

# %%
movies_5000[movies_5000["release_date"]>="2017-01-01"]
# Out:
#       budget                                             genres  \
# 4445       0  [{"id": 35, "name": "Comedy"}, {"id": 10751, "...
#
#                                 homepage      id keywords original_language  \
# 4445  http://www.growingupsmithmovie.com  426469       []                en
#
#         original_title                                           overview  \
# 4445  Growing Up Smith  In 1979, an Indian family moves to America wit...
#
#       popularity production_companies production_countries release_date  \
# 4445     0.71087                   []                   []   2017-02-03
#
#       revenue  runtime                          spoken_languages    status  \
# 4445        0    102.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                        tagline             title  \
# 4445  It’s better to stand out than to fit in.  Growing Up Smith
#
#       vote_average  vote_count
# 4445           7.4           7
